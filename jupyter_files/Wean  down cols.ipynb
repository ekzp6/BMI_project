# %%
import pandas as pd
import numpy as np

# %%
data =  pd.read_excel('Preprocessed.xlsx')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Column1', 'Block', 'Column', 'Row', 'Name', 'ID', 'X',
#        'Y', 'Dia.', 'F532 Median', 'F532 Mean', 'F532 SD', 'F532 CV', 'B532',
#        'B532 Median', 'B532 Mean', 'B532 SD', 'B532 CV', '% > B532+1SD',
#        '% > B532+2SD', 'F532 % Sat.', 'F635 Median', 'F635 Mean', 'F635 SD',
#        'F635 CV', 'B635', 'B635 Median', 'B635 Mean', 'B635 SD', 'B635 CV',
#        '% > B635+1SD', '% > B635+2SD', 'F635 % Sat.',
#        'Ratio of Medians (532/635)', 'Ratio of Means (532/635)',
#        'Median of Ratios (532/635)', 'Mean of Ratios (532/635)',
#        'Ratios SD (532/635)', 'Rgn Ratio (532/635)', 'Rgn R2 (532/635)',
#        'F Pixels', 'B Pixels', 'Circularity', 'Sum of Medians (532/635)',
#        'Sum of Means (532/635)', 'Log Ratio (532/635)', 'F532 Median - B532',
#        'F635 Median - B635', 'F532 Mean - B532', 'F635 Mean - B635',
#        'F532 Total Intensity', 'F635 Total Intensity', 'SNR 532', 'SNR 635',
# ...

# %%
 Keep = ['Samples ID*', 'Description*', 'Type*', 'Array platform', 'Name', 
         'ID', 'Dia.',  'F532 Median - B532', 'F635 Median - B635', ]

# %%
data = data[Keep]

# %%
data
# Out:
#       Samples ID*      Description*  Type* Array platform              Name  \
# 0             534  COVID-19 pateint  Serum           #1-1          S1_0.1_T
# 1             534  COVID-19 pateint  Serum           #1-1          S1_0.1_S
# 2             534  COVID-19 pateint  Serum           #1-1         S1_0.25_S
# 3             534  COVID-19 pateint  Serum           #1-1          S1_0.5_S
# 4             534  COVID-19 pateint  Serum           #1-1          S1_0.1_B
# ...           ...               ...    ...            ...               ...
# 21499        NC65           Control  Serum          #3-14    Anti-H-IgG_0.1
# 21500        NC65           Control  Serum          #3-14  Anti-H-IgM_0.025
# 21501        NC65           Control  Serum          #3-14    Anti-H-IgM_0.1
# 21502        NC65           Control  Serum          #3-14               Cy5
# 21503        NC65           Control  Serum          #3-14               Cy3
#
#         ID  Dia.  F532 Median - B532  F635 Median - B635
# ...
